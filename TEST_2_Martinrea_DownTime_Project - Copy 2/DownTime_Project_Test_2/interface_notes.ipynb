# %% [markdown]
# # Post-Login Interface Notes
#
# This notebook documents the new main screen layout that appears after login. The login code remains unchanged. The actual template file is `templates/management.html`, and the supporting styles were added to `static/css/style.css`.

# %% [markdown]
# ## Updated `templates/management.html`
#
# The new page layout includes:
# - top header with logo and live date/time
# - a second navigation bar with tabs
# - a left side panel with the user avatar
# - a main content area with a motors line diagram style card

# %% [markdown]
# ```html
# {% extends 'base.html' %}
# {% block content %}
# <div class="app-shell">
#   <header class="app-topbar">...
# </div>
# {% endblock %}
# ```

# %% [markdown]
# ## Added CSS rules
#
# The new styles were appended to `static/css/style.css` and include classes for the app shell, top bar, tabs, side panel, and diagram card.

# %% [markdown]
# ```css
# .app-shell { ... }
# .app-topbar { ... }
# .tab { ... }
# ```

# %% [markdown]
# ## Side menu and controls
#
# The left panel now includes:
# - a user block with avatar and description
# - `START` for simulation
# - `UPDATE` for GitHub updates
# - `LOG OUT` to return to the login screen
# - `EXIT` to stop the app server if available
